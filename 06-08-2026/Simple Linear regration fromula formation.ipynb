# %%
class lr:
    def __init__(self):
        self.m= None
        self.b= None
        

    def fit(self,x_train,y_train):
        num=0
        den=0
        for i in range (x_train.shape[0]):
            num=num+((x_train[i]-x_train.mean())*(y_train[i] - y_train.mean()))
            den=den+(x_train[i]-x_train.mean())*(x_train[i]-x_train.mean())

        self.m=num/den
        self.b=y_train.mean()-(self.m*x_train.mean())
        print(self.b)

    def predict(self,x_test):
        return self.m*x_test + self.b

# %%
import pandas as pd

# %%
df=pd.read_csv('placement.csv')

# %%
df.sample(5)
# Out:
#      cgpa  package
# 118  7.40     2.88
# 161  7.30     3.33
# 27   5.42     2.16
# 78   6.59     2.21
# 182  5.88     2.08

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,0].values,df.iloc[:,1].values,test_size=0.2)

# %%
Ilr=lr()

# %%
Ilr.fit(x_train,y_train)
# Out:
# -1.0372476413000573

# %%
Ilr.predict(x_test[0])
# Out:
# np.float64(2.9158907961075267)

# %%
x_test[0]
# Out:
# np.float64(6.86)
